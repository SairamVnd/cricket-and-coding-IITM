# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\vndsa'

# %%
os.chdir("C:\\Users\\vndsa\\Desktop\\Cricket and Coding\\DataSet")

# %%
df_b2b=pd.read_csv("IPL_Ball_by_Ball_2008_2022.csv")

# %%
df_b2b.head(100)
# Out:
#          ID  innings  overs  ballnumber       batter          bowler  \
# 0   1312200        1      0           1  YBK Jaiswal  Mohammed Shami
# 1   1312200        1      0           2  YBK Jaiswal  Mohammed Shami
# 2   1312200        1      0           3   JC Buttler  Mohammed Shami
# 3   1312200        1      0           4  YBK Jaiswal  Mohammed Shami
# 4   1312200        1      0           5  YBK Jaiswal  Mohammed Shami
# ..      ...      ...    ...         ...          ...             ...
# 95  1312200        1     15           6     TA Boult   R Sai Kishore
# 96  1312200        1     16           1      R Parag     LH Ferguson
# 97  1312200        1     16           2     TA Boult     LH Ferguson
# 98  1312200        1     16           3      R Parag     LH Ferguson
# 99  1312200        1     16           4     TA Boult     LH Ferguson
#
#     non-striker extra_type  batsman_run  extras_run  total_run  non_boundary  \
# ...

# %%
df_b2b.shape
# Out:
# (225954, 17)

# %%
df_b2b.columns
# Out:
# Index(['ID', 'innings', 'overs', 'ballnumber', 'batter', 'bowler',
#        'non-striker', 'extra_type', 'batsman_run', 'extras_run', 'total_run',
#        'non_boundary', 'isWicketDelivery', 'player_out', 'kind',
#        'fielders_involved', 'BattingTeam'],
#       dtype='object')

# %%
df_b2b.describe()
# Out:
#                  ID        innings          overs     ballnumber  \
# count  2.259540e+05  225954.000000  225954.000000  225954.000000
# mean   8.320470e+05       1.483868       9.185679       3.619750
# std    3.379542e+05       0.503104       5.681797       1.810633
# min    3.359820e+05       1.000000       0.000000       1.000000
# 25%    5.012620e+05       1.000000       4.000000       2.000000
# 50%    8.297370e+05       1.000000       9.000000       4.000000
# 75%    1.178395e+06       2.000000      14.000000       5.000000
# max    1.312200e+06       6.000000      19.000000      10.000000
#
#          batsman_run     extras_run     total_run   non_boundary  \
# count  225954.000000  225954.000000  225954.00000  225954.000000
# mean        1.243523       0.066907       1.31043       0.000093
# std         1.618166       0.341470       1.60605       0.009640
# min         0.000000       0.000000       0.00000       0.000000
# ...

# %%
df_b2b.isnull().sum()
# Out:
# ID                        0
# innings                   0
# overs                     0
# ballnumber                0
# batter                    0
# bowler                    0
# non-striker               0
# extra_type           213905
# batsman_run               0
# extras_run                0
# total_run                 0
# non_boundary              0
# isWicketDelivery          0
# player_out           214803
# kind                 214803
# fielders_involved    217966
# BattingTeam               0
# dtype: int64

# %%
corr=df_b2b.corr()
display(corr)
sns.heatmap(corr,annot=True)
plt.show
# Out:
#                         ID   innings     overs  ballnumber  batsman_run  \
# ID                1.000000  0.002039  0.009295    0.001006     0.024467
# innings           0.002039  1.000000 -0.050497   -0.004535    -0.005425
# overs             0.009295 -0.050497  1.000000   -0.003695     0.084464
# ballnumber        0.001006 -0.004535 -0.003695    1.000000     0.004527
# batsman_run       0.024467 -0.005425  0.084464    0.004527     1.000000
# extras_run       -0.012086  0.000203  0.001674    0.000162    -0.140860
# total_run         0.022082 -0.005422  0.085457    0.004596     0.977595
# non_boundary      0.001513  0.000765 -0.001689   -0.002286     0.019828
# isWicketDelivery -0.000873  0.000340  0.073935    0.004143    -0.170370
#
#                   extras_run  total_run  non_boundary  isWicketDelivery
# ID                 -0.012086   0.022082      0.001513         -0.000873
# innings             0.000203  -0.005422      0.000765          0.000340
# ...

# %%
df_b2b.apply(lambda x:len(x.unique()))
# Out:
# ID                   950
# innings                6
# overs                 20
# ballnumber            10
# batter               605
# bowler               472
# non-striker          595
# extra_type             6
# batsman_run            7
# extras_run             7
# total_run              8
# non_boundary           2
# isWicketDelivery       2
# player_out           574
# kind                  11
# fielders_involved    536
# BattingTeam           18
# dtype: int64

# %%
unq_batter=df_b2b["batter"].unique()
#print(unq_batter)
len(unq_batter)
# Out:
# 605

# %%
unq_bowler=df_b2b["bowler"].unique()
#print(unq_bowler)
len(unq_bowler)
# Out:
# 472

# %%
unq_extra_type=df_b2b["extra_type"].unique()
print(unq_extra_type)
len(unq_extra_type)
# Out:
# [nan 'legbyes' 'wides' 'byes' 'noballs' 'penalty']
# 6

# %%
#sns.pairplot(df_b2b)

# %%
print(df_b2b.loc[df_b2b['batter'] == "YBK Jaiswal"])
print(df_b2b.loc[(df_b2b['batter'] == "YBK Jaiswal") | (df_b2b['batter'] == "Virat Kohli")])
# Out:
#             ID  innings  overs  ballnumber       batter          bowler  \
# 0      1312200        1      0           1  YBK Jaiswal  Mohammed Shami
# 1      1312200        1      0           2  YBK Jaiswal  Mohammed Shami
# 3      1312200        1      0           4  YBK Jaiswal  Mohammed Shami
# 4      1312200        1      0           5  YBK Jaiswal  Mohammed Shami
# 5      1312200        1      0           6  YBK Jaiswal  Mohammed Shami
# ...        ...      ...    ...         ...          ...             ...
# 45713  1216496        1      0           2  YBK Jaiswal       DL Chahar
# 45714  1216496        1      0           3  YBK Jaiswal       DL Chahar
# 45722  1216496        1      1           5  YBK Jaiswal       SM Curran
# 45725  1216496        1      2           1  YBK Jaiswal       DL Chahar
# 45726  1216496        1      2           2  YBK Jaiswal       DL Chahar
#
#       non-striker extra_type  batsman_run  extras_run  total_run  \
# ...

# %%
df_b2b.shape
# Out:
# (225954, 17)

# %% [markdown]
# # 6 Overs Data

# %%
df_b2b_6overs=df_b2b.loc[(df_b2b['overs'] == 0) | (df_b2b['overs'] == 1) | (df_b2b['overs'] == 2) | (df_b2b['overs'] == 3) | (df_b2b['overs'] == 4) | (df_b2b['overs'] == 5)]
df_b2b_6overs
# Out:
#              ID  innings  overs  ballnumber       batter          bowler  \
# 0       1312200        1      0           1  YBK Jaiswal  Mohammed Shami
# 1       1312200        1      0           2  YBK Jaiswal  Mohammed Shami
# 2       1312200        1      0           3   JC Buttler  Mohammed Shami
# 3       1312200        1      0           4  YBK Jaiswal  Mohammed Shami
# 4       1312200        1      0           5  YBK Jaiswal  Mohammed Shami
# ...         ...      ...    ...         ...          ...             ...
# 225886   335982        2      5           2     W Jaffer        AB Dinda
# 225887   335982        2      5           3   MV Boucher        AB Dinda
# 225888   335982        2      5           4   MV Boucher        AB Dinda
# 225889   335982        2      5           5     CL White        AB Dinda
# 225890   335982        2      5           6   MV Boucher        AB Dinda
#
#         non-striker extra_type  batsman_run  extras_run  total_run  \
# ...

# %%
df_b2b_6overs.shape
# Out:
# (71082, 17)

# %%
df_b2b.shape[0]-df_b2b_6overs.shape[0]
# Out:
# 154872

# %%
sns.boxplot(y=df_b2b_6overs["innings"])
plt.show()
sns.histplot(df_b2b_6overs["innings"])
plt.show()

# %%
for j in df_b2b.columns.values:
    if df_b2b_6overs[j].dtypes=="int64":
        print("-------",j,"--------","-------",j,"--------","-------",j,"--------","-------",j,"--------")
        sns.boxplot(y=df_b2b_6overs[j])
        
        plt.title(f"{j}_Boxplot")
        plt.show()
    
        sns.histplot(df_b2b_6overs[j])
        plt.title(f"{j}_Histogram ")
        plt.show()
        print("--------------------------------------------XXXXXXX-------------------------------------------------- \n \n ")
# Out:
# ------- ID -------- ------- ID -------- ------- ID -------- ------- ID --------
# --------------------------------------------XXXXXXX--------------------------------------------------
#
#
# ------- innings -------- ------- innings -------- ------- innings -------- ------- innings --------
# --------------------------------------------XXXXXXX--------------------------------------------------
#
#
# ------- overs -------- ------- overs -------- ------- overs -------- ------- overs --------
# --------------------------------------------XXXXXXX--------------------------------------------------
#
#
# ------- ballnumber -------- ------- ballnumber -------- ------- ballnumber -------- ------- ballnumber --------
# --------------------------------------------XXXXXXX--------------------------------------------------
#
#
# ------- batsman_run -------- ------- batsman_run -------- ------- batsman_run -------- ------- batsman_run --------
# ...

# %%
# Out:
# ID T
# innings T
# overs T
# ballnumber T
# batter T
# bowler T
# non-striker T
# extra_type T
# batsman_run T
# extras_run T
# total_run T
# non_boundary T
# isWicketDelivery T
# player_out T
# kind T
# fielders_involved T
# BattingTeam T

# %%
unq_batter_6overs=df_b2b_6overs["batter"].unique()
#print(unq_batter)
len(unq_batter_6overs)
# Out:
# 326

# %%
df_b2b_6overs.apply(lambda x:len(x.unique()))
# Out:
# ID                   950
# innings                6
# overs                  6
# ballnumber            10
# batter               326
# bowler               383
# non-striker          315
# extra_type             6
# batsman_run            7
# extras_run             7
# total_run              8
# non_boundary           2
# isWicketDelivery       2
# player_out           269
# kind                   9
# fielders_involved    388
# BattingTeam           18
# dtype: int64

# %%
pd.options.display.max_rows = None

df_b2b_6overs["batter"].value_counts()
# Out:
# S Dhawan             2656
# DA Warner            2196
# G Gambhir            1945
# V Kohli              1881
# CH Gayle             1851
# AM Rahane            1837
# RV Uthappa           1697
# PA Patel             1630
# RG Sharma            1428
# M Vijay              1416
# KL Rahul             1307
# SR Watson            1292
# Q de Kock            1283
# BB McCullum          1278
# SK Raina             1210
# F du Plessis         1185
# V Sehwag             1160
# AC Gilchrist         1080
# SR Tendulkar         1035
# JH Kallis            1024
# MA Agarwal           1008
# DR Smith             1003
# MK Pandey             992
# JC Buttler            882
# SV Samson             870
# R Dravid              855
# AJ Finch              826
# SS Iyer               808
# MEK Hussey            791
# PP Shaw               787
# SE Marsh              753
# Shubman Gill          751
# AT Rayudu             750
# WP Saha               749
# AB de Villiers        630
# ...

# %%
#sns.displot(data=df_b2b_6overs,x="batter",height=100,aspect=1.5)

# %%
score_sum = df_b2b_6overs[df_b2b_6overs['batter'] =="S Dhawan" ].sum()
# Out:
# C:\Users\vndsa\AppData\Local\Temp\ipykernel_17672\1547706465.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   score_sum = df_b2b_6overs[df_b2b_6overs['batter'] =="S Dhawan" ].sum()

# %%
score_sum
# Out:
# ID                                                         2424591113
# innings                                                          3791
# overs                                                            6185
# ballnumber                                                       9487
# batter              S DhawanS DhawanS DhawanS DhawanS DhawanS Dhaw...
# bowler              Washington SundarFazalhaq FarooqiFazalhaq Faro...
# non-striker         JM BairstowJM BairstowJM BairstowM Shahrukh Kh...
# batsman_run                                                      3157
# extras_run                                                        172
# total_run                                                        3329
# non_boundary                                                        0
# isWicketDelivery                                                   86
# BattingTeam         Punjab KingsPunjab KingsPunjab KingsPunjab Kin...
# dtype: object

# %%
 
a = df_b2b_6overs[df_b2b_6overs['batter'] == 'Sohail Tanvir']['batsman_run'].sum()
a
# Out:
# 13

# %%
set_batter=list(set(df_b2b_6overs["batter"].values))

set_batter
# Out:
# ['SK Raina',
#  'Ramandeep Singh',
#  'T Kohli',
#  'Lalit Yadav',
#  'MS Wade',
#  'F du Plessis',
#  'YK Pathan',
#  'Shakib Al Hasan',
#  'S Chanderpaul',
#  'JP Duminy',
#  'Q de Kock',
#  'P Negi',
#  'A Manohar',
#  'BJ Haddin',
#  'Misbah-ul-Haq',
#  'Washington Sundar',
#  'AN Ghosh',
#  'Shubman Gill',
#  'RV Gomez',
#  'JM Bairstow',
#  'GH Vihari',
#  'RA Bawa',
#  'SP Jackson',
#  'S Sriram',
#  'D Brevis',
#  'RK Singh',
#  'SM Pollock',
#  'S Dube',
#  'KD Karthik',
#  'NK Patel',
#  'C de Grandhomme',
#  'UA Birla',
#  'EJG Morgan',
#  'SP Narine',
#  'JC Buttler',
#  'B Chipli',
#  'V Shankar',
#  'SP Fleming',
#  'V Kohli',
#  'HR Shokeen',
#  'MC Juneja',
#  'AA Jhunjhunwala',
#  'NV Ojha',
#  'AD Mascarenhas',
#  'TL Suman',
#  'AR Patel',
#  'SE Marsh',
#  'LJ Wright',
#  'W Jaffer',
#  'T Stubbs',
#  'S Badrinath',
#  'V Sehwag',
#  'Salman Butt',
#  'DJ Willey',
#  'CH Morris',
#  'AB Barath',
#  'MK Lomror',
#  'NJ Maddinson',
#  'A Symonds',
#  'JD Ryder',
# ...

# %%
for i in set_batter:
    runs=df_b2b_6overs[df_b2b_6overs['batter'] == i]['batsman_run'].sum()
    print(i,"-",runs)
# Out:
# SK Raina - 1560
# Ramandeep Singh - 2
# T Kohli - 7
# Lalit Yadav - 23
# MS Wade - 113
# F du Plessis - 1480
# YK Pathan - 361
# Shakib Al Hasan - 37
# S Chanderpaul - 25
# JP Duminy - 235
# Q de Kock - 1634
# P Negi - 4
# A Manohar - 12
# BJ Haddin - 18
# Misbah-ul-Haq - 27
# Washington Sundar - 17
# AN Ghosh - 7
# Shubman Gill - 882
# RV Gomez - 0
# JM Bairstow - 695
# GH Vihari - 59
# RA Bawa - 0
# SP Jackson - 10
# S Sriram - 13
# D Brevis - 65
# RK Singh - 9
# SM Pollock - 1
# S Dube - 30
# KD Karthik - 397
# NK Patel - 45
# C de Grandhomme - 1
# UA Birla - 6
# EJG Morgan - 176
# SP Narine - 665
# JC Buttler - 1230
# B Chipli - 55
# V Shankar - 45
# SP Fleming - 120
# V Kohli - 2135
# HR Shokeen - 1
# MC Juneja - 20
# AA Jhunjhunwala - 24
# NV Ojha - 494
# AD Mascarenhas - 4
# TL Suman - 185
# AR Patel - 11
# SE Marsh - 779
# LJ Wright - 8
# W Jaffer - 77
# T Stubbs - 0
# S Badrinath - 182
# V Sehwag - 1593
# Salman Butt - 104
# DJ Willey - 6
# CH Morris - 17
# AB Barath - 18
# ...

# %%
runs_6overs=[]
for i in set_batter:
    runs=df_b2b_6overs[df_b2b_6overs['batter'] == i]['batsman_run'].sum()
    runs_6overs.append(runs)
    
runs_6overs
# Out:
# [1560,
#  2,
#  7,
#  23,
#  113,
#  1480,
#  361,
#  37,
#  25,
#  235,
#  1634,
#  4,
#  12,
#  18,
#  27,
#  17,
#  7,
#  882,
#  0,
#  695,
#  59,
#  0,
#  10,
#  13,
#  65,
#  9,
#  1,
#  30,
#  397,
#  45,
#  1,
#  6,
#  176,
#  665,
#  1230,
#  55,
#  45,
#  120,
#  2135,
#  1,
#  20,
#  24,
#  494,
#  4,
#  185,
#  11,
#  779,
#  8,
#  77,
#  0,
#  182,
#  1593,
#  104,
#  6,
#  17,
#  18,
#  28,
#  20,
#  72,
#  440,
#  4,
#  14,
#  57,
#  1,
#  58,
#  1036,
#  5,
#  9,
#  278,
#  23,
#  0,
#  19,
#  1600,
#  1129,
#  15,
#  10,
#  779,
#  99,
#  76,
#  8,
#  543,
#  52,
#  6,
#  18,
#  741,
#  41,
#  225,
#  510,
#  8,
#  0,
#  115,
#  727,
#  7,
#  1213,
#  828,
#  0,
#  1904,
#  14,
#  777,
#  18,
#  53,
#  522,
#  467,
#  15,
#  2,
#  7,
#  374,
#  125,
#  120,
#  215,
#  522,
#  103,
#  261,
#  631,
#  1,
#  26,
#  27,
#  0,
#  14,
#  2,
#  2,
#  0,
#  6,
#  17,
#  18,
#  92,
#  20,
#  107,
#  0,
#  193,
#  62,
#  131,
#  2405,
#  26,
#  169,
#  131,
#  2037,
#  599,
# ...

# %%
df1=pd.DataFrame({"batter_6overs": set_batter,"total runs": runs_6overs})

# %%
df1_sorted = df1.sort_values(by="batter_6overs")
df1_sorted
# Out:
#          batter_6overs  total runs
# 66      A Ashish Reddy           5
# 306           A Badoni           1
# 269           A Chopra          27
# 61          A Flintoff          14
# 12           A Manohar          12
# 311           A Mishra           1
# 142           A Mukund          14
# 58           A Symonds          72
# 208            A Tomar           4
# 259        AA Bilakhia          23
# 41     AA Jhunjhunwala          24
# 235         AB Agarkar          20
# 55           AB Barath          18
# 273        AB McDonald          30
# 84      AB de Villiers         741
# 77         AC Blizzard          99
# 288       AC Gilchrist        1385
# 169           AC Voges           7
# 290           AD Hales         114
# 43      AD Mascarenhas           4
# 145         AD Mathews          10
# 194            AD Nath          11
# 262         AD Russell          41
# 170        AG Paunikar          49
# 256           AJ Finch         911
# 322         AK Markram          25
# ...

# %%
df_b2b_6overs["batter"].value_counts().sort_index()
# Out:
# A Ashish Reddy          7
# A Badoni                7
# A Chopra               41
# A Flintoff             15
# A Manohar              12
# A Mishra                5
# A Mukund               16
# A Symonds              86
# A Tomar                 8
# AA Bilakhia            33
# AA Jhunjhunwala        36
# AB Agarkar             15
# AB Barath              14
# AB McDonald            19
# AB de Villiers        630
# AC Blizzard            77
# AC Gilchrist         1080
# AC Voges                9
# AD Hales               82
# AD Mascarenhas          2
# AD Mathews             17
# AD Nath                12
# AD Russell             17
# AG Paunikar            61
# AJ Finch              826
# AK Markram             36
# AL Menaria              8
# AM Nayar               76
# AM Rahane            1837
# AN Ghosh                7
# AP Majumdar            15
# AP Tare               214
# AR Patel               15
# AS Raut                 6
# AT Rayudu             750
# ...

# %%
df1_sorted["total_balls_faced"]=list(df_b2b_6overs["batter"].value_counts().sort_index())
df1_sorted["strike_rate"]=df1_sorted["total runs"]/df1_sorted["total_balls_faced"]*100
df1_sorted.sort_values(by="total_balls_faced")
df1_sorted
# Out:
#          batter_6overs  total runs  total_balls_faced  strike_rate
# 66      A Ashish Reddy           5                  7    71.428571
# 306           A Badoni           1                  7    14.285714
# 269           A Chopra          27                 41    65.853659
# 61          A Flintoff          14                 15    93.333333
# 12           A Manohar          12                 12   100.000000
# 311           A Mishra           1                  5    20.000000
# 142           A Mukund          14                 16    87.500000
# 58           A Symonds          72                 86    83.720930
# 208            A Tomar           4                  8    50.000000
# 259        AA Bilakhia          23                 33    69.696970
# 41     AA Jhunjhunwala          24                 36    66.666667
# 235         AB Agarkar          20                 15   133.333333
# 55           AB Barath          18                 14   128.571429
# ...

# %% [markdown]
# # match ID/no of unique matchs

# %%
 





runs_6overs=[]
for i in set_batter:
    runs=df_b2b_6overs[df_b2b_6overs['batter'] == i]['batsman_run'].sum()
    runs_6overs.append(runs)
    
runs_6overs
# Out:
# [1560,
#  2,
#  7,
#  23,
#  113,
#  1480,
#  361,
#  37,
#  25,
#  235,
#  1634,
#  4,
#  12,
#  18,
#  27,
#  17,
#  7,
#  882,
#  0,
#  695,
#  59,
#  0,
#  10,
#  13,
#  65,
#  9,
#  1,
#  30,
#  397,
#  45,
#  1,
#  6,
#  176,
#  665,
#  1230,
#  55,
#  45,
#  120,
#  2135,
#  1,
#  20,
#  24,
#  494,
#  4,
#  185,
#  11,
#  779,
#  8,
#  77,
#  0,
#  182,
#  1593,
#  104,
#  6,
#  17,
#  18,
#  28,
#  20,
#  72,
#  440,
#  4,
#  14,
#  57,
#  1,
#  58,
#  1036,
#  5,
#  9,
#  278,
#  23,
#  0,
#  19,
#  1600,
#  1129,
#  15,
#  10,
#  779,
#  99,
#  76,
#  8,
#  543,
#  52,
#  6,
#  18,
#  741,
#  41,
#  225,
#  510,
#  8,
#  0,
#  115,
#  727,
#  7,
#  1213,
#  828,
#  0,
#  1904,
#  14,
#  777,
#  18,
#  53,
#  522,
#  467,
#  15,
#  2,
#  7,
#  374,
#  125,
#  120,
#  215,
#  522,
#  103,
#  261,
#  631,
#  1,
#  26,
#  27,
#  0,
#  14,
#  2,
#  2,
#  0,
#  6,
#  17,
#  18,
#  92,
#  20,
#  107,
#  0,
#  193,
#  62,
#  131,
#  2405,
#  26,
#  169,
#  131,
#  2037,
#  599,
# ...
